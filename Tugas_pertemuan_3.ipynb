# %% [markdown]
# <a href="https://colab.research.google.com/github/khoirulanam61417-ux/Khoirul-Anam/blob/main/Tugas_pertemuan_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# upload file dari komputer / HP
from google.colab import files
uploaded = files.upload()
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('gojo.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Negative
negative = 255 - img

# Logaritmik
img_float = img.astype(np.float32)
c = 255 / np.log(1 + np.max(img_float))
log_image = c * np.log(1 + img_float)
log_image = np.array(log_image, dtype=np.uint8)

# Power Law (Gamma)
gamma = 0.5
power = np.array(255*(img/255)**gamma, dtype='uint8')

# Display
plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Gambar Asli")
plt.axis("off")

plt.subplot(2,2,2)
plt.imshow(negative)
plt.title("Negative")
plt.axis("off")

plt.subplot(2,2,3)
plt.imshow(log_image)
plt.title("Logaritmik")
plt.axis("off")

plt.subplot(2,2,4)
plt.imshow(power)
plt.title("Power Law (Gamma)")
plt.axis("off")

plt.show()
# Out:
#      <input type="file" id="files-b7c30f1f-8385-46c7-9d6c-dcaffa942181" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b7c30f1f-8385-46c7-9d6c-dcaffa942181">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
